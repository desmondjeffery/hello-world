# %% [markdown]
# <a href="https://colab.research.google.com/github/desmondjeffery/hello-world/blob/master/Untitled0.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Instructions

# %% [markdown]
# 1.   Follow [this link](https://drive.google.com/drive/folders/1q7SThfCMGCqantGtyH0LcTowWioC0cyn?usp=sharing) to access the statsbomb:
#
# 2.   Once you have access to the shared folder, right-click on the folder name and select "Add shortcut to Drive" (see image below)
# ![add_shortcut.PNG](data:image/png;base64,...)
#
# 3. Navigate to the left-hand side of this Google Colab workbook. Click on the folder icon.

# %%
from google.colab import drive 
drive.mount('/content/drive')

#I can change stuff do it
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %%
os.
